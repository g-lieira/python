# %% [markdown]
# <a href="https://colab.research.google.com/github/g-lieira/python/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1

D = {'Jogador':'Antonio', 'Idade':25, 'Posição':'Atacante', 'Lesionado?':False}
print(D.keys())
# Out:
# dict_keys(['Jogador', 'Idade', 'Posição', 'Lesionado'])

# %%
#exercicio 2

horas_aula = 50
quantidade_disciplinas = 3
professora = 'Ana Lucia'
horas_trabalhadas = horas_aula * quantidade_disciplinas
print(f'{professora} ministrou {horas_trabalhadas} horas de aulas.')
# Out:
# Ana Lucia ministrou 150 horas de aulas.

# %%
#exercicio 3

for numero in range(10):
  print(f'Numero {numero}')
# Out:
# Numero 0
# Numero 1
# Numero 2
# Numero 3
# Numero 4
# Numero 5
# Numero 6
# Numero 7
# Numero 8
# Numero 9

# %%
#exercicio 4

velocidade = 115

if velocidade <=0:
  print('Parado!')
elif (velocidade < 40):
  print('Lento')
elif (velocidade < 100):
  print('Dentro do limite')
else:
  print('Acima do limite')
# Out:
# Acima do limite

# %%
#exercicio 5

cont = 30
while cont >= 20:
  print(cont, end = ' - ')
  cont = cont - 1
# Out:
# 30 - 29 - 28 - 27 - 26 - 25 - 24 - 23 - 22 - 21 - 20 -

# %%
#exercicio 6

try:
  numerador = 10
  denominador = 0
  resultado = numerador / denominador
  print(f'O resultado da divisão é {resultado:.2f}')
except:
  print('Não é possível calcular a divisão')
# Out:
# Não é possível calcular a divisão

# %%
#exercicio 7

def Multiplica(A, B):
  R = A * B
  return R

a = 3
b = 2
M = Multiplica(a, b)
print(M)
# Out:
# 6

# %%
#exercicio 8

a = {'A', 'B', 'C', 'D', 'E', 'F'}
a.add('H')
a.add('A')
a.add('B')
a.add('J')

print(a)
# Out:
# {'C', 'B', 'D', 'E', 'A', 'H', 'F', 'J'}

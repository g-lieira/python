# %% [markdown]
# <a href="https://colab.research.google.com/github/g-lieira/python/blob/main/Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercício 2
aluno = ['Pedro', 20, 8.5, 'Londrina']

print(aluno[1])
# Out:
# 20

# %%
#exercicio 3

cursos = ['python', 'java', 'c++', 'c#', 'pascal']
curso_escolhido = input('Digite o nome do curso que você deseja se inscrever: ').lower()

if curso_escolhido in cursos:
  print(f'O curso "{curso_escolhido}" está disponível para inscrição')
else:
  print(f'O curso "{curso_escolhido}" não está disponível no momento')
# Out:
# Digite o nome do curso que você deseja se inscrever: pascal
# O curso "pascal" está disponível para inscrição

# %%
#exercicio 4

L = [5, 10, 15, 20]
print(12 in L)
# Out:
# False

# %%
#exercicio 5
L = [5, 10, 15, 20, 25, 30]

L.reverse()
#L.index(-1)
#L.sort()
#L.extend()
#L.clear()

print(L)
# Out:
# [30, 25, 20, 15, 10, 5]

# %%
#exercicio 6

L = [['A', 'B', 'C'], ['D', 'E', 'F', 'H']]

#print(L[1][0])
#print(L[1][2])
#print(L[0][1])
print(L[1][1])
#print(L[2])
# Out:
# E

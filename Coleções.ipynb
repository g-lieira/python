# %% [markdown]
# <a href="https://colab.research.google.com/github/g-lieira/python/blob/main/Cole%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1

disciplinas1 = ('Matemática', 'História')
disciplinas2 = ('Português', 'Ciências')
disciplinas3 = ('Geografia', 'Artes')

#materias = disciplinas1, disciplinas3, disciplinas2
materias = disciplinas1 + disciplinas3 + disciplinas2
#materias = disciplinas1 + disciplinas2 + disciplinas3
#materias = (disciplinas1, disciplinas3, disciplinas2)

print(materias)
# Out:
# ('Matemática', 'História', 'Geografia', 'Artes', 'Português', 'Ciências')

# %%
#exericio 2

T = (5, 'Python', 3.14, True)
T = T + (False, [1, 2])
print(T)
# Out:
# (5, 'Python', 3.14, True, False, [1, 2])

# %%
#exercicio 3

a = {1, 2, 3, 4, 5, 6}
b = {3, 6, 9}
c = a.intersection(b)
print(c)
# Out:
# {3, 6}

# %%
#exercicio 4

a = {1, 2, 3, 4, 5, 6}
a.add(6)
a.add(7)
a.add(8)
a.add(9)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
#exercicio 5

estoque_frutas = {
    'Maçã': 15,
    'Banana': 8,
    'Laranja': 12,
    'Uva': 10
}

print("Quantidades disponíveis no estoque:")
for quantidade in estoque_frutas.values():
  print(f"Quantidade: {quantidade}")
# Out:
# Quantidades disponíveis no estoque:
# Quantidade: 15
# Quantidade: 8
# Quantidade: 12
# Quantidade: 10

# %%
#exercicio 6

D = {'Nome': 'Carlos', 'Idade': 42, 'Profissão': 'Advogado', 'Contratado': True}

print(D.values())
# Out:
# dict_values(['Carlos', 42, 'Advogado', True])

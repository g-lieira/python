# %% [markdown]
# <a href="https://colab.research.google.com/github/g-lieira/python/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1
nome = 'Paulo'
saudacao = 'Tenha um bom dia'
saida = 'Olá, ' + nome + ". " + saudacao + '!'
print(saida)
# Out:
# Olá, Paulo. Tenha um bom dia!

# %%
#exericico 2
S = 'linguagem de programação python'

print(S.swapcase())
print(S.capitalize())
print(S.lower())
print(S.title())
print(S.upper())
# Out:
# LINGUAGEM DE PROGRAMAÇÃO PYTHON
# Linguagem de programação python
# linguagem de programação python
# Linguagem De Programação Python
# LINGUAGEM DE PROGRAMAÇÃO PYTHON

# %%
#exercicio 3
frase = "UTFPR"

print(frase[::2])
print(frase[::-1])
print(frase[0:3])
# Out:
# UFR
# RPFTU
# UTF

# %%
#exercicio 4

D = 'Texto'

print(f'({len(D)}) ({D[0]}) ({D[-1]})')
# Out:
# (5) (T) (o)

# %%
#exercicio 5
S = "Universidade Tecnológica Federal do Paraná"

print(S[13:])
print(S[13:24])
print(f'{S[0]}{S[13]}{S[25]}{S[36]}{S[38].upper()}')
# Out:
# Tecnológica Federal do Paraná
# Tecnológica
# UTFPR

# %%
#exericico 6

S = 'Sou estudante da Univesidade Tecnológica Federal do Paraná'
#T = S.count('Universidade Tecnológica Federal do Paraná', 'UTFPR')
#T = S.split('Universidade Tecnológica Federal do Paraná', 'UTFPR')
#T = S.find('Universidade Tecnológica Federal do Paraná', 'UTFPR')
T = S.replace('Univesidade Tecnológica Federal do Paraná', 'UTFPR')
#T = S.isalpha('Universidade Tecnológica Federal do Paraná', 'UTFPR')
print(T)
# Out:
# Sou estudante da UTFPR

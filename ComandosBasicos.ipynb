# %% [markdown]
# <a href="https://colab.research.google.com/github/g-lieira/python/blob/main/ComandosBasicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1
print('Tenham um bom dia')
# Out:
# Tenham um bom dia

# %%
#exercicio 2
cidade = input('Qual o nome da sua cidade? ')
print(f'O nome da minha cidade é {cidade}.')
# Out:
# Qual o nome da sua cidade? Londrina
# O nome da minha cidade é Londrina.

# %%
#exercicio 3
A = 6
B = 4
C = 2

R = A + B * C
S = A / B + C

print(f'{R} e {S}')
# Out:
# 14 e 3.5

# %%
#exercicio 4
valor_hora = 10
nome = 'Laura'
horas_trabalhadas = 40
salario = valor_hora * horas_trabalhadas

print('{} trabalhou {} horas e recebeu R${:.2f}'.format(nome, horas_trabalhadas, salario))

print('%s trabalhou %d horas e recebeu R$%.2f' % (nome, horas_trabalhadas, salario))

print(f'{nome} trabalhou {horas_trabalhadas} horas e recebeu R${salario:.2f}')

print(f'{nome} trabalhou {horas_trabalhadas} horas e recebeu R${salario}')
# Out:
# Laura trabalhou 40 horas e recebeu R$400.00
# Laura trabalhou 40 horas e recebeu R$400.00
# Laura trabalhou 40 horas e recebeu R$400.00
# Laura trabalhou 40 horas e recebeu R$400

# %%
#exercicio 6
A = 4
B = 2

C=A**B
D=A/B
E=A%B

print(f'{C}, {D} e {E}')
# Out:
# 16, 2.0 e 0
